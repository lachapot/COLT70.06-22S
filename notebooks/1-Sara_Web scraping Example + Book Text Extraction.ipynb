# %%
# gets the html for soup to look at
from bs4 import BeautifulSoup
import requests

URL = 'https://www.thedartmouth.com/article/2022/04/22s-covid-19-live-blog'
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")

result = soup.find_all('p')

for r in result:
    print(r.text)
# Out:
# April 27, 2022 | Latest Issue
#
#
#
#
#
#
#
#
#
#
#
#
#
# Follow along for the latest COVID-19 developments on campus
#
#                                                 by The Dartmouth Senior Staff
#                                                                                                  | 4/20/22 8:28pm
#
#
#
# Active cases spike to spring term high of 329 cases.
#  April 20 | 8:30 p.m.
# As of Tuesday, there are 525 reported active cases of COVID-19 on campus, an increase from the 329 active cases reported on April 13, according to the College COVID-19 dashboard. In an email sent to campus on April 19, provost David Kotz wrote that current case counts represent self-reported positive cases, as well as symptomatic and voluntary on-campus tests.
#
#
#
# ...

# %%
# gets the html for soup to look at
from bs4 import BeautifulSoup
import requests

URL = 'https://www.thedartmouth.com/article/2022/04/22s-covid-19-live-blog'
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")

result = soup.find_all('p')

for r in result:
    print(r.text)

# %%
# gets the html for soup to look at
from bs4 import BeautifulSoup
import requests

URL = 'https://myanimelist.net/forum/?topicid=2011275'
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")

result = soup.find_all('div')

for r in result:
    print(r.text)
# Out:
# MyAnimeList.net
#
#
#
#
#
# Hide AdsLoginSign Up
# AllAnimeMangaCharactersPeopleCompaniesManga StoreNewsFeatured ArticlesForumClubsUsers
#               View all results for ${ keyword }
#
# Anime
#
# Anime Search
# Top Anime
# Seasonal Anime
# Videos
# Reviews
# Recommendations
# 2022 ChallengeFantasy Anime League
#
# Manga
#
# Manga Search
# Top Manga
# Manga Store
# Reviews
# Recommendations
# 2022 Challenge
#
#
# Community
#
# Interest Stacks
# Forums
# Clubs
# Blogs
# Users
#
#
# Industry
#
# News
# Featured Articles
# People
# Characters
# Companies
# MAL×Japan
#
#
# Watch
#
# Episode Videos
# Anime Trailers
#
# Read
#
# Manga Store
#
#
# Help
#
# About
# Support
# Advertising
# FAQ
# Report
# StaffMAL Supporter
#
#
#
#  Forum SettingsEpisode InformationForums
#
#               Top
#                             >
#               Anime
#                             >
#               Spy x Family
#                             >
#               Spy x Family Episode 3 Discuss...
#
# ...

# %%
# gets the html for soup to look at
from bs4 import BeautifulSoup
import requests

URL = 'https://myanimelist.net/forum/?topicid=2011275'
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")

result = soup.find_all('div', class_ = 'clearfix')

for i in range(len(result)):
    if i % 2 == 0:
        print(result[i].text)
# Out:
#               Top
#                             >
#               Anime
#                             >
#               Spy x Family
#                             >
#               Spy x Family Episode 3 Discuss...
#
#
#               Top
#                             >
#               Forum
#                             >
#               Anime Series Discussion
#                             >
#               Title Discussion
#                             >
#               Spy x Family Episode 3 Discuss...
#
#
#
# RecentWatchedIgnoredSearch Forum
# Spy x Family Episode 3 Discussion
# Cool episode, nothing too special in my eyes, but it goes to show, with the house tour thing and the outing the three had, even for a fake family, stuff is indeed wholesome, it's really nice to watch lol.
#
# That robbery scene was fun too, nice help from all to take the dude down, guess that's the benefits of overpowered family lol.  BBCode
#
# Uuuuuuuuuuuuuuuuuuuuuuuuuuuniverse ‼
# ...

# %%
pip install pdf2image
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/local/bin/python3.7 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pytesseract
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/local/bin/python3.7 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pillow

# %%
PDF_file = '/Users/sarakay/Susan J. Napier - Anime from Akira to Princess Mononoke_ Experiencing Contemporary Japanese Animation (2001).pdf'
from pdf2image import convert_from_path
'''
Part #1 : Converting PDF to images
'''
  
# Store all the pages of the PDF in a variable
pages = convert_from_path(PDF_file, 500)
  
# Counter to store images of each page of PDF to image
image_counter = 1
  
# Iterate through all the pages stored above
for page in pages:
  
    # Declaring filename for each page of PDF as JPG
    # For each page, filename will be:
    # PDF page 1 -> page_1.jpg
    # PDF page 2 -> page_2.jpg
    # PDF page 3 -> page_3.jpg
    # ....
    # PDF page n -> page_n.jpg
    filename = "page_"+str(image_counter)+".jpg"
      
    # Save the image of the page in system
    page.save(filename, 'JPEG')
  
    # Increment the counter to update filename
    image_counter = image_counter + 1
  
'''
Part #2 - Recognizing text from the images using OCR
'''
    
# Variable to get count of total number of pages
filelimit = image_counter-1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/sf/b607g6w95rq9hv8v55xc25km0000gn/T/ipykernel_77301/97838273.py in <module>
#      55
#      56     # Recognize the text as string in image using pytesserct
# ---> 57     text = str(((pytesseract.image_to_string(Image.open(filename)))))
#      58
#      59     # The recognized text is stored in variable text
#
# NameError: name 'pytesseract' is not defined

# %%
import pytesseract
from PIL import Image
# Creating a text file to write the output
outfile = "out_text.txt"
  
# Open the file in append mode so that 
# All contents of all images are added to the same file
f = open(outfile, "a")
  
# Iterate from 1 to total number of pages
for i in range(1, filelimit + 1):
  
    # Set filename to recognize text from
    # Again, these files will be:
    # page_1.jpg
    # page_2.jpg
    # ....
    # page_n.jpg
    filename = "page_"+str(i)+".jpg"
          
    # Recognize the text as string in image using pytesserct
    text = str(((pytesseract.image_to_string(Image.open(filename)))))
  
    # The recognized text is stored in variable text
    # Any string processing may be applied on text
    # Here, basic formatting has been done:
    # In many PDFs, at line ending, if a word can't
    # be written fully, a 'hyphen' is added.
    # The rest of the word is written in the next line
    # Eg: This is a sample text this word here GeeksF-
    # orGeeks is half on first line, remaining on next.
    # To remove this, we replace every '-\n' to ''.
    text = text.replace('-\n', '')    
  
    # Finally, write the processed text to the file.
    f.write(text)
  
# Close the file after writing all the text.
f.close()
